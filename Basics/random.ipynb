# %%
import numpy as np

# %%
def MSE(logits, y):
    return np.mean(np.sum((y - logits) ** 2))

class Model():
    def __init__(self, weights, lr):
        self.w = weights
        self.lr = lr

    def forward(self, x):
        self.x = x
        self.y = 0
        self.y = x @ self.w
        return self.y
    
    def grad(self):
        dl_dw = -2 * (model.y - model.x * self.w) * self.x
        return dl_dw

    def loss(logits, y):
        return MSE(logits, y)

    def backward(self):
        self.w -= self.lr * model.grad

data = np.array([9,10,11,12])
x = data

width = 4
w_0 = np.random.rand(len(x), width)
lr = 0.01
epochs = 10

model = Model(w_0, lr)

for e in range(epochs):
    model.forward(x)
    model.backward()
